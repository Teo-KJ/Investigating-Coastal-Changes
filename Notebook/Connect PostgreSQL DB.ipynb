# %%
import psycopg2
from functions import *
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'postgres://pjumfrukhciszx:ad1784376a00c8c76e087a197dec4df12358eb842e159c0e61b134f5a61fe112@ec2-176-34-105-15.eu-west-1.compute.amazonaws.com:5432/dd6dtn4idlbb1'

conn = psycopg2.connect(url, sslmode='require')
conn
# Out:
# <connection object at 0x0000019F60F94D08; dsn: 'user=pjumfrukhciszx password=xxx dbname=dd6dtn4idlbb1 host=ec2-176-34-105-15.eu-west-1.compute.amazonaws.com port=5432 sslmode=require', closed: 0>

# %%
# command = (
#         '''
#         ALTER TABLE temp RENAME TO polygonData
#         '''
#         )

# setUpDB(command, url)

# %%
query = "SELECT * FROM polygonData;"

data = getData(query, url)
print('Length of dataframe:', len(data))

data
# Out:
# Length of dataframe: 6
#                  location                                            polygon  \
# 0      Cuddalore, India 1  [[[79.777394, 11.767001], [79.795799, 11.76700...
# 1  TLW and TTW, Hong Kong  [[[22.2429, 114.231062], [22.2429, 114.261954]...
# 2        Phuket, Thailand  [[[8.191042, 98.279705], [8.191042, 98.315021]...
# 3    Tanauan, Philippines  [[[125.017687, 11.114658], [125.026614, 11.114...
# 4        Cuddalore, India  [[[11.918064, 79.80787], [11.918064, 79.841008...
# 5   San Jose, Philippines  [[[11.432049, 125.512816], [11.432049, 125.644...
#
#   folder_name
# 0     India 1
# 1   Hong Kong
# 2    Thailand
# 3     Tanauan
# 4       India
# 5    San Jose

# %%
query = "SELECT * FROM shorelineData;"

getData(query, url).head(10)
# Out:
#            location                dates  \
# 0  Cuddalore, India  2021-01-30 05:15:30
# 1  Cuddalore, India  2021-02-24 05:15:29
# 2  Cuddalore, India  2021-03-06 05:15:29
# 3  Cuddalore, India  2021-04-30 05:15:28
# 4  Cuddalore, India  2004-12-02 04:44:20
# 5  Cuddalore, India  2004-12-18 04:44:39
# 6  Cuddalore, India  2005-01-03 04:44:52
# 7  Phuket, Thailand  2004-09-09 03:29:13
# 8  Phuket, Thailand  2004-12-30 03:31:27
# 9  Phuket, Thailand  2005-01-15 03:31:38
#
#                                           shorelines  \
# 0  [[8885164.762856377, 1336397.1992373508], [888...
# 1  [[8886870.065451143, 1336404.472443062], [8886...
# 2  [[8886870.673116347, 1336404.4750178955], [888...
# 3  [[8886870.582054563, 1336404.4746320439], [888...
# 4  [[8885616.312642546, 1336345.128181252], [8885...
# 5  [[8885214.844328862, 1336405.1293524683], [888...
# 6  [[8885642.439999908, 1336345.2399418203], [888...
# 7  [[10944299.415360982, 909346.8988171098], [109...
# 8  [[10942812.506545687, 907252.4143558767], [109...
# 9  [[10942803.820818858, 907252.3992824683], [109...
#
#                                   filename  cloud_cover  geoaccuracy  idx  \
# 0  2021-01-30-05-15-30_S2_India S2_10m.tif     0.000000        1.000    9
# 1  2021-02-24-05-15-29_S2_India S2_10m.tif     0.000000        1.000   14
# 2  2021-03-06-05-15-29_S2_India S2_10m.tif     0.000000        1.000   16
# 3  2021-04-30-05-15-28_S2_India S2_10m.tif     0.000000        1.000   25
# 4      2004-12-02-04-44-20_L5_India L5.tif     0.004014        4.715    0
# 5      2004-12-18-04-44-39_L5_India L5.tif     0.006905        4.380    1
# 6      2005-01-03-04-44-52_L5_India L5.tif     0.000000        4.250    2
# 7   2004-09-09-03-29-13_L5_Thailand L5.tif     0.103808        4.074    0
# 8   2004-12-30-03-31-27_L5_Thailand L5.tif     0.000000        3.799    7
# 9   2005-01-15-03-31-38_L5_Thailand L5.tif     0.000000        4.281    8
#
#   satname
# 0      S2
# 1      S2
# 2      S2
# 3      S2
# 4      L5
# 5      L5
# 6      L5
# 7      L5
# 8      L5
# 9      L5
