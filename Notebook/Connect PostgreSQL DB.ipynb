# %%
import psycopg2
from functions import *
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'postgres://pjumfrukhciszx:ad1784376a00c8c76e087a197dec4df12358eb842e159c0e61b134f5a61fe112@ec2-176-34-105-15.eu-west-1.compute.amazonaws.com:5432/dd6dtn4idlbb1'

conn = psycopg2.connect(url, sslmode='require')
conn
# Out:
# <connection object at 0x0000027CC0AA4BF8; dsn: 'user=pjumfrukhciszx password=xxx dbname=dd6dtn4idlbb1 host=ec2-176-34-105-15.eu-west-1.compute.amazonaws.com port=5432 sslmode=require', closed: 0>

# %%
# command = (
#         """
#         CREATE TABLE shorelineData (
#             location VARCHAR NOT NULL,
#             date VARCHAR NOT NULL,
#             shorelines VARCHAR,
#             filename VARCHAR NOT NULL,
#             cloud_cover FLOAT NOT NULL,
#             geoaccuracy FLOAT NOT NULL,
#             idx SMALLINT NOT NULL,
#             satname VARCHAR NOT NULL
#         )
#         """)

# command = (
#         """
#         CREATE TABLE polygonData (
#             location VARCHAR NOT NULL,
#             polygon VARCHAR NOT NULL
#         )
#         """)

# command = (
#         """
#         ALTER TABLE shorelineData RENAME COLUMN date TO dates;
#         """)

# command = (
#         """
#         DROP TABLE polygonData
#         """)

# command = (
#         '''
#         DELETE FROM shorelineData
#         WHERE location = 'Cuddalore, India';
#         ''')

# command = (
#         '''
#         DELETE FROM shorelineData
#         WHERE date > '2020-01-01'
#         '''
#             )
# SET date = date || '+00:00'

# command = (
#         '''
#         UPDATE shorelineData
#         SET date = LEFT(date, LENGTH(date)-6)
#         WHERE LENGTH(date)>19;
#         '''
#         )

# command = (
#         '''
#         INSERT INTO polygonData
#         VALUES ('TLW and TTW, Hong Kong', '%s', 'Hong Kong');
#         ''' % a
#         )

# command = (
#         '''
#         ALTER TABLE polygonData 
#         ADD COLUMN folder_name VARCHAR;
#         '''
#         )

# command = (
#         '''
#         UPDATE polygonData SET folder_name = 'San Jose'
#         WHERE location = 'San Jose, Philippines'
#         '''
#         )

command = (
        '''
        UPDATE polygonData SET folder_name = 'San Jose'
        WHERE location = 'San Jose, Philippines'
        '''
        )

UPDATE shorelineData
SET location = 'TLW and TTW, Hong Kong',
WHERE location = 'HK TLW and TTW';

# setUpDB(command, url)

# %%
query = "SELECT * FROM shorelineData ORDER BY location, dates;"
# query = "SELECT * FROM shorelineData WHERE location = 'HK TLW and TTW' ORDER BY dates;"
# query = "SELECT DISTINCT location FROM shorelineData;"
# query = "SELECT * FROM polygonData;"

data = getData(query, url)

print('Length of dataframe:', len(data))

data#.head()
# Out:
# Length of dataframe: 58
#                   location                dates  \
# 0         Cuddalore, India  2004-12-02 04:44:20
# 1         Cuddalore, India  2004-12-18 04:44:39
# 2         Cuddalore, India  2005-01-03 04:44:52
# 3         Cuddalore, India  2020-12-26 05:15:28
# 4         Cuddalore, India  2021-01-30 05:15:30
# 36   2021-03-10-04-05-54_S2_Thailand S2_10m.tif     0.000000        1.000
# 37   2013-09-03-01-55-11_L7_San Jose L7_pan.tif     0.045730        4.525
# 38   2013-11-15-01-49-40_L7_San Jose L7_pan.tif     0.049926        6.327
# 39    2013-07-09-02-01-40_L8_Tanauan L8_pan.tif     0.000000        8.398
# 40    2013-07-25-02-01-39_L8_Tanauan L8_pan.tif     0.028637        8.460
# 41    2013-11-30-02-01-18_L8_Tanauan L8_pan.tif     0.000000        8.072
# 42    2014-02-18-02-00-30_L8_Tanauan L8_pan.tif     0.000000        7.996
# 43    2014-03-06-02-00-15_L8_Tanauan L8_pan.tif     0.002490        8.294
# 44      2008-08-20-02-32-07_L5_Hong Kong L5.tif     0.000000        4.543
# 45      2008-09-21-02-31-13_L5_Hong Kong L5.tif     0.000000        4.378
# 46      2008-10-23-02-30-09_L5_Hong Kong L5.tif     0.006280        4.196
# 47      2008-11-24-02-29-54_L5_Hong Kong L5.tif     0.000000        3.762
# 48      2008-12-01-02-35-54_L5_Hong Kong L5.tif     0.000000        4.554
# 49      2008-12-01-02-36-18_L5_Hong Kong L5.tif     0.000000        3.974
# 50      2008-12-10-02-30-24_L5_Hong Kong L5.tif     0.000000        3.668
# 51      2008-12-17-02-36-23_L5_Hong Kong L5.tif     0.000000        4.554
# 52      2008-12-17-02-36-47_L5_Hong Kong L5.tif     0.000000        3.990
# 53      2009-01-02-02-36-50_L5_Hong Kong L5.tif     0.000000        4.804
# 54      2009-01-02-02-37-14_L5_Hong Kong L5.tif     0.000000        4.131
# 55      2009-01-11-02-31-17_L5_Hong Kong L5.tif     0.000000        3.375
# 56      2009-01-18-02-37-15_L5_Hong Kong L5.tif     0.000000        5.673
# 57      2009-01-18-02-37-39_L5_Hong Kong L5.tif     0.000000        3.799
#
#     idx satname
# 0     0      L5
# 1     1      L5
# 2     2      L5
# 3     4      S2
# 4     9      S2
# 5    10      S2
# 6    14      S2
# 7    15      S2
# 8    16      S2
# 9    18      S2
# 10   25      S2
# 11    0      S2
# 12    1      S2
# 13    8      S2
# 14    9      S2
# 15   10      S2
# 16   14      S2
# 17   19      S2
# 18   22      S2
# 19   25      S2
# 20   27      S2
# 21   29      S2
# 22   37      S2
# 23   39      S2
# 24   48      S2
# 25    0      L5
# 26    7      L5
# 27    8      L5
# 28    9      L5
# 29    1      S2
# 30    8      S2
# 31    9      S2
# 32   12      S2
# 33   13      S2
# 34   15      S2
# 35   17      S2
# 36   18      S2
# 37    1      L7
# 38    6      L7
# 39    2      L8
# 40    3      L8
# 41    9      L8
# 42   11      L8
# 43   12      L8
# 44    1      L5
# 45    7      L5
# 46   10      L5
# 47   15      L5
# 48   16      L5
# 49   17      L5
# 50   18      L5
# 51   19      L5
# 52   20      L5
# 53   21      L5
# 54   22      L5
# 55   23      L5
# 56   24      L5
# 57   25      L5
