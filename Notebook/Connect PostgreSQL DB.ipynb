# %%
import psycopg2
from functions import *
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'postgres://pjumfrukhciszx:ad1784376a00c8c76e087a197dec4df12358eb842e159c0e61b134f5a61fe112@ec2-176-34-105-15.eu-west-1.compute.amazonaws.com:5432/dd6dtn4idlbb1'

conn = psycopg2.connect(url, sslmode='require')
conn
# Out:
# <connection object at 0x0000011387EA6048; dsn: 'user=pjumfrukhciszx password=xxx dbname=dd6dtn4idlbb1 host=ec2-176-34-105-15.eu-west-1.compute.amazonaws.com port=5432 sslmode=require', closed: 0>

# %%
# command = (
#         """
#         CREATE TABLE shorelineData (
#             location VARCHAR NOT NULL,
#             date VARCHAR NOT NULL,
#             shorelines VARCHAR,
#             filename VARCHAR NOT NULL,
#             cloud_cover FLOAT NOT NULL,
#             geoaccuracy FLOAT NOT NULL,
#             idx SMALLINT NOT NULL,
#             satname VARCHAR NOT NULL
#         )
#         """)

# command = (
#         """
#         ALTER TABLE shorelineData RENAME COLUMN dates TO date;
#         """)

# command = (
#         """
#         DROP TABLE shorelineData
#         """)

# command = (
#         '''
#         DELETE FROM shorelineData
#         WHERE location = 'Cuddalore, India';
#         ''')

# command = (
#         '''
#         DELETE FROM shorelineData
#         WHERE date > '2020-01-01'
#         '''
#             )
# SET date = date || '+00:00'

command = (
        '''
        UPDATE shorelineData
        SET date = LEFT(date, LENGTH(date)-6)
        WHERE LENGTH(date)>19;
        '''
        )

setUpDB(command, url)
# Out:
# done

# %%
query = "SELECT * FROM shorelineData"
# query = "SELECT * FROM shorelineData WHERE date > '2020-01-01'"

data = getData(query, url)
data
# Out:
#                   location                 date  \
# 0         Cuddalore, India  2021-01-30 05:15:30
# 1         Cuddalore, India  2021-02-24 05:15:29
# 2         Cuddalore, India  2021-03-06 05:15:29
# 3         Cuddalore, India  2021-04-30 05:15:28
# 4         Cuddalore, India  2004-12-02 04:44:20
# 5         Cuddalore, India  2004-12-18 04:44:39
# 6         Cuddalore, India  2005-01-03 04:44:52
# 7         Phuket, Thailand  2004-09-09 03:29:13
# 8         Phuket, Thailand  2004-12-30 03:31:27
# 9         Phuket, Thailand  2005-01-15 03:31:38
# 10        Phuket, Thailand  2005-01-31 03:31:50
# 11   San Jose, Philippines  2013-09-03 01:55:11
# 12   San Jose, Philippines  2013-11-15 01:49:40
# 13    Tanauan, Philippines  2013-07-09 02:01:40
# 14    Tanauan, Philippines  2013-07-25 02:01:39
# 15    Tanauan, Philippines  2013-11-30 02:01:18
# 16        Cuddalore, India  2020-12-26 05:15:28
# 17        Cuddalore, India  2021-02-04 05:15:30
# 18        Cuddalore, India  2021-03-01 05:15:30
# 19        Cuddalore, India  2021-03-16 05:15:30
# 20    Tanauan, Philippines  2014-02-18 02:00:30
# 21    Tanauan, Philippines  2014-03-06 02:00:15
# 22  TLW and TTW, Hong Kong  2008-08-20 02:32:07
# 23  TLW and TTW, Hong Kong  2008-09-21 02:31:13
# 24  TLW and TTW, Hong Kong  2009-01-02 02:37:14
# 25  TLW and TTW, Hong Kong  2009-01-11 02:31:17
# 26  TLW and TTW, Hong Kong  2009-01-18 02:37:15
# 5          2004-12-18-04-44-39_L5_India L5.tif     0.006905        4.380    1
# 6          2005-01-03-04-44-52_L5_India L5.tif     0.000000        4.250    2
# 7       2004-09-09-03-29-13_L5_Thailand L5.tif     0.103808        4.074    0
# 8       2004-12-30-03-31-27_L5_Thailand L5.tif     0.000000        3.799    7
# 9       2005-01-15-03-31-38_L5_Thailand L5.tif     0.000000        4.281    8
# 10      2005-01-31-03-31-50_L5_Thailand L5.tif     0.000000        4.327    9
# 11  2013-09-03-01-55-11_L7_San Jose L7_pan.tif     0.045730        4.525    1
# 12  2013-11-15-01-49-40_L7_San Jose L7_pan.tif     0.049926        6.327    6
# 13   2013-07-09-02-01-40_L8_Tanauan L8_pan.tif     0.000000        8.398    2
# 14   2013-07-25-02-01-39_L8_Tanauan L8_pan.tif     0.028637        8.460    3
# 15   2013-11-30-02-01-18_L8_Tanauan L8_pan.tif     0.000000        8.072    9
# 16     2020-12-26-05-15-28_S2_India S2_10m.tif     0.000000        1.000    4
# 17     2021-02-04-05-15-30_S2_India S2_10m.tif     0.000000        1.000   10
# 18     2021-03-01-05-15-30_S2_India S2_10m.tif     0.000000        1.000   15
# 19     2021-03-16-05-15-30_S2_India S2_10m.tif     0.000000        1.000   18
# 20   2014-02-18-02-00-30_L8_Tanauan L8_pan.tif     0.000000        7.996   11
# 21   2014-03-06-02-00-15_L8_Tanauan L8_pan.tif     0.002490        8.294   12
# 22     2008-08-20-02-32-07_L5_Hong Kong L5.tif     0.000000        4.543    1
# 23     2008-09-21-02-31-13_L5_Hong Kong L5.tif     0.000000        4.378    7
# 24     2009-01-02-02-37-14_L5_Hong Kong L5.tif     0.000000        4.131   22
# 25     2009-01-11-02-31-17_L5_Hong Kong L5.tif     0.000000        3.375   23
# 26     2009-01-18-02-37-15_L5_Hong Kong L5.tif     0.000000        5.673   24
# 27     2009-01-18-02-37-39_L5_Hong Kong L5.tif     0.000000        3.799   25
# 28     2008-10-23-02-30-09_L5_Hong Kong L5.tif     0.006280        4.196   10
# 29     2008-11-24-02-29-54_L5_Hong Kong L5.tif     0.000000        3.762   15
# 30     2008-12-01-02-35-54_L5_Hong Kong L5.tif     0.000000        4.554   16
# 31     2008-12-01-02-36-18_L5_Hong Kong L5.tif     0.000000        3.974   17
# 32     2008-12-10-02-30-24_L5_Hong Kong L5.tif     0.000000        3.668   18
# 33     2008-12-17-02-36-23_L5_Hong Kong L5.tif     0.000000        4.554   19
# 34     2008-12-17-02-36-47_L5_Hong Kong L5.tif     0.000000        3.990   20
# 35     2009-01-02-02-36-50_L5_Hong Kong L5.tif     0.000000        4.804   21
#
#    satname
# 0       S2
# 1       S2
# 2       S2
# 3       S2
# 4       L5
# 5       L5
# 6       L5
# 7       L5
# 8       L5
# 9       L5
# 10      L5
# 11      L7
# 12      L7
# 13      L8
# 14      L8
# 15      L8
# 16      S2
# 17      S2
# 18      S2
# 19      S2
# 20      L8
# 21      L8
# 22      L5
# 23      L5
# 24      L5
# 25      L5
# 26      L5
# 27      L5
# 28      L5
# 29      L5
# 30      L5
# 31      L5
# 32      L5
# 33      L5
# 34      L5
# 35      L5
