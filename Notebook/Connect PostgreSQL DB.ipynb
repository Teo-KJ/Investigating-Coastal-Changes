# %%
import psycopg2
from functions import *
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'postgres://pjumfrukhciszx:ad1784376a00c8c76e087a197dec4df12358eb842e159c0e61b134f5a61fe112@ec2-176-34-105-15.eu-west-1.compute.amazonaws.com:5432/dd6dtn4idlbb1'

conn = psycopg2.connect(url, sslmode='require')
conn
# Out:
# <connection object at 0x000001A3AB39FBF8; dsn: 'user=pjumfrukhciszx password=xxx dbname=dd6dtn4idlbb1 host=ec2-176-34-105-15.eu-west-1.compute.amazonaws.com port=5432 sslmode=require', closed: 0>

# %%
# command = (
#         """
#         CREATE TABLE shorelineData (
#             location VARCHAR NOT NULL,
#             date VARCHAR NOT NULL,
#             shorelines VARCHAR,
#             filename VARCHAR NOT NULL,
#             cloud_cover FLOAT NOT NULL,
#             geoaccuracy FLOAT NOT NULL,
#             idx SMALLINT NOT NULL,
#             satname VARCHAR NOT NULL
#         )
#         """)

# command = (
#         """
#         CREATE TABLE polygonData (
#             location VARCHAR NOT NULL,
#             polygon VARCHAR NOT NULL
#         )
#         """)

# command = (
#         """
#         ALTER TABLE shorelineData RENAME COLUMN date TO dates;
#         """)

# command = (
#         """
#         DROP TABLE polygonData
#         """)

# command = (
#         '''
#         DELETE FROM shorelineData
#         WHERE location = 'Cuddalore, India';
#         ''')

# command = (
#         '''
#         DELETE FROM shorelineData
#         WHERE date > '2020-01-01'
#         '''
#             )
# SET date = date || '+00:00'

# command = (
#         '''
#         UPDATE shorelineData
#         SET date = LEFT(date, LENGTH(date)-6)
#         WHERE LENGTH(date)>19;
#         '''
#         )

# command = (
#         '''
#         INSERT INTO polygonData
#         VALUES ('TLW and TTW, Hong Kong', '%s', 'Hong Kong');
#         ''' % a
#         )

# command = (
#         '''
#         ALTER TABLE polygonData 
#         ADD COLUMN folder_name VARCHAR;
#         '''
#         )

# command = (
#         '''
#         UPDATE polygonData SET folder_name = 'San Jose'
#         WHERE location = 'San Jose, Philippines'
#         '''
#         )

# command = (
#         '''
#         UPDATE shorelineData
#         SET location = 'TLW and TTW, Hong Kong'
#         WHERE location = 'HK TLW and TTW';
#         '''
#         )

# setUpDB(command, url)

# %%
# query = "SELECT * FROM shorelineData ORDER BY location, dates;"
query = "SELECT * FROM shorelineData WHERE location = 'TLW and TTW, Hong Kong' ORDER BY dates;"
# query = "SELECT DISTINCT location FROM shorelineData;"
# query = "SELECT * FROM polygonData;"

data = getData(query, url)

print('Length of dataframe:', len(data))

data#.head()
# Out:
# Length of dataframe: 28
#                   location                dates  \
# 0   TLW and TTW, Hong Kong  2008-08-20 02:32:07
# 1   TLW and TTW, Hong Kong  2008-09-21 02:31:13
# 2   TLW and TTW, Hong Kong  2008-10-23 02:30:09
# 20  [[12717990.812135085, 2540752.8444428435], [12...
# 21  [[12717987.49970166, 2540752.783813883], [1271...
# 22  [[12717993.053606266, 2540752.885469127], [127...
# 23  [[12717974.301874807, 2540752.542241612], [127...
# 24  [[12717997.025691707, 2540752.9581705974], [12...
# 25  [[12717998.197545908, 2540752.9796189805], [12...
# 26  [[12716049.473614696, 2540706.7177368775], [12...
# 27  [[12718006.419015413, 2540753.1300937803], [12...
#
#                                        filename  cloud_cover  geoaccuracy  \
# 0       2008-08-20-02-32-07_L5_Hong Kong L5.tif      0.00000        4.543
# 1       2008-09-21-02-31-13_L5_Hong Kong L5.tif      0.00000        4.378
# 2       2008-10-23-02-30-09_L5_Hong Kong L5.tif      0.00628        4.196
# 3       2008-11-24-02-29-54_L5_Hong Kong L5.tif      0.00000        3.762
# 4       2008-12-01-02-35-54_L5_Hong Kong L5.tif      0.00000        4.554
# 5       2008-12-01-02-36-18_L5_Hong Kong L5.tif      0.00000        3.974
# 6       2008-12-10-02-30-24_L5_Hong Kong L5.tif      0.00000        3.668
# 7       2008-12-17-02-36-23_L5_Hong Kong L5.tif      0.00000        4.554
# 8       2008-12-17-02-36-47_L5_Hong Kong L5.tif      0.00000        3.990
# 9       2009-01-02-02-36-50_L5_Hong Kong L5.tif      0.00000        4.804
# 10      2009-01-02-02-37-14_L5_Hong Kong L5.tif      0.00000        4.131
# 11      2009-01-11-02-31-17_L5_Hong Kong L5.tif      0.00000        3.375
# 12      2009-01-18-02-37-15_L5_Hong Kong L5.tif      0.00000        5.673
# 13      2009-01-18-02-37-39_L5_Hong Kong L5.tif      0.00000        3.799
# 14  2020-12-02-03-01-48_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 15  2020-12-05-03-11-42_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 16  2020-12-27-03-01-46_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 17  2020-12-30-03-11-42_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 18  2021-01-01-03-01-48_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 19  2021-01-14-03-11-44_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 20  2021-01-26-03-01-48_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 21  2021-02-03-03-11-43_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 22  2021-02-13-03-11-42_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 23  2021-02-18-03-11-41_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 24  2021-02-23-03-11-43_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 25  2021-03-17-03-01-48_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 26  2021-03-25-03-11-42_S2_Hong Kong S2_10m.tif      0.00000        1.000
# 27  2021-04-21-03-01-44_S2_Hong Kong S2_10m.tif      0.00000        1.000
#
#     idx satname
# 0     1      L5
# 1     7      L5
# 2    10      L5
# 3    15      L5
# 4    16      L5
# 5    17      L5
# 6    18      L5
# 7    19      L5
# 8    20      L5
# 9    21      L5
# 10   22      L5
# 11   23      L5
# 12   24      L5
# 13   25      L5
# 14    0      S2
# 15    1      S2
# 16    8      S2
# 17    9      S2
# 18   10      S2
# 19   14      S2
# 20   19      S2
# 21   22      S2
# 22   25      S2
# 23   27      S2
# 24   29      S2
# 25   37      S2
# 26   39      S2
# 27   48      S2
